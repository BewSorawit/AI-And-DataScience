# %% [markdown]
# ### Model linear regression

# %% [markdown]
# #### import

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### จำลองข้อมูล

# %%
rng = np.random

# %%
x = rng.rand(50) * 10
y = 2 * x + rng.randn(50)

# %%
print(x)
# Out:
# [0.49873991 4.56009954 4.97354177 2.65214304 8.27338985 0.095959
#  7.33101517 4.50362833 6.75869522 4.29846177 5.08621873 7.1499352
#  0.90152249 3.49925499 2.14516598 2.47205694 5.96527521 5.75436326
#  3.16187022 6.78742825 4.27324482 5.26346701 0.12308052 4.8403329
#  6.4315577  8.63924262 8.84758974 9.33443416 0.7529994  0.55415529
#  7.98127878 8.29640284 7.3415045  5.57184042 8.12848847 4.50160723
#  5.57980726 4.6391555  2.01892067 5.7050743  4.98488996 9.17005205
#  4.91350273 4.33990437 5.51475483 6.61998786 4.90793589 2.89272224
#  6.46387215 2.87201886]

# %%
x_new = x.reshape(-1,1)

# %%
print(x_new)
# Out:
# [[0.49873991]
#  [4.56009954]
#  [4.97354177]
#  [2.65214304]
#  [8.27338985]
#  [0.095959  ]
#  [7.33101517]
#  [4.50362833]
#  [6.75869522]
#  [4.29846177]
#  [5.08621873]
#  [7.1499352 ]
#  [0.90152249]
#  [3.49925499]
#  [2.14516598]
#  [2.47205694]
#  [5.96527521]
#  [5.75436326]
#  [3.16187022]
#  [6.78742825]
#  [4.27324482]
#  [5.26346701]
#  [0.12308052]
#  [4.8403329 ]
#  [6.4315577 ]
#  [8.63924262]
#  [8.84758974]
#  [9.33443416]
#  [0.7529994 ]
#  [0.55415529]
#  [7.98127878]
#  [8.29640284]
#  [7.3415045 ]
#  [5.57184042]
#  [8.12848847]
#  [4.50160723]
#  [5.57980726]
#  [4.6391555 ]
#  [2.01892067]
#  [5.7050743 ]
#  [4.98488996]
#  [9.17005205]
#  [4.91350273]
#  [4.33990437]
#  [5.51475483]
#  [6.61998786]
#  [4.90793589]
#  [2.89272224]
#  [6.46387215]
#  [2.87201886]]

# %%
print(y)
# Out:
# [ 0.86612778  7.64529143  9.19000307  2.97118374 17.61740791 -1.64267224
#  15.61520092  8.67209795 12.22906161  8.71883998  9.8245172  14.1442231
#   0.65295003  8.87690524  5.36662989  3.61964274 12.43143627 11.59779119
#   4.57519242 16.65028765  8.94633738 11.90571983  0.24093654 10.48251192
#  11.98847992 15.60778544 17.79634238 18.50139847  2.34996651 -0.35220974
#  15.60415294 15.66384496 14.40984723 10.38792062 15.30488369  9.40360558
#  10.77268483  9.89136299  3.46009134 13.18144018 10.38986518 19.54101393
#   9.37611754  7.19429698 10.36077649 11.30913947 10.81366372  6.999673
#  12.08002258  5.33118717]

# %% [markdown]
# #### model linear regression

# %%
model = LinearRegression()

# %% [markdown]
# #### train model

# %%
# model.fit(x.reshape(-1,1),y)
model.fit(x_new,y)
# Out:
# LinearRegression()

# %%
print("R-SQuare", model.score(x_new,y))
print("Intercept", model.intercept_)
print("Coef",model.coef_)
# Out:
# R-SQuare 0.9550415437818616
# Intercept -0.47291833680669093
# Coef [2.0622682]

# %% [markdown]
# #### test

# %%
xfit = np.linspace(-1,11)
xfit_new = xfit.reshape(-1,1)

# %%
print(xfit_new.shape)
# Out:
# (50, 1)

# %%
yfit = model.predict(xfit_new)

# %% [markdown]
# #### Analysis model & result

# %%
plt.scatter(x,y)
plt.plot(xfit,yfit)
plt.show()
