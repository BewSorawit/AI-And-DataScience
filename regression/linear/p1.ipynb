# %% [markdown]
# ### example data

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Generate some random data
np.random.seed(0)

X = np.random.rand(50) * 10   # Independent variable
print(X.shape)
Y = 2 * X + np.random.randn(50) * 2   # Dependent variable with added noise

# Calculate correlation coefficient
r = np.corrcoef(X, Y)[0, 1]
print(f"Correlation coefficient: {r}")

# Perform simple linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)

# Print slope and intercept
print(f"Slope (beta1): {slope}")
print(f"Intercept (beta0): {intercept}")

# Plotting the data and regression line
plt.scatter(X, Y, label='Data points')
plt.plot(X, intercept + slope * X, color='red', label='Linear regression line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# (50,)
# Correlation coefficient: 0.9437136072736597
# Slope (beta1): 1.9385465894619038
# Intercept (beta0): -0.014420168260551591

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate synthetic data
np.random.seed(0)
X = 2 * np.random.rand(100, 1)   # Generate 100 random numbers between 0 and 2
print(X.shape)
y = 3 + 4 * X + np.random.randn(100, 1)  # y = 3 + 4*X + noise

# Create a linear regression model
model = LinearRegression()

# Fit the model
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Plot the results
plt.scatter(X, y, color='blue', label='Original data')
plt.plot(X, y_pred, color='red', linewidth=3, label='Fitted line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()
# Out:
# (100, 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# ข้อมูลตัวอย่าง
X = np.array([1, 2, 3, 4, 5, 6]).reshape(-1, 1)  # แปลงให้เป็น matrix 1 คอลัมน์
y = np.array([1.2, 2.1, 2.9, 4.2, 5.1, 5.8])

# สร้างแบบจำลอง Linear Regression
model = LinearRegression()
model.fit(X, y)

# ทำนายค่า y จาก X
y_pred = model.predict(X)

# พล็อตกราฟ
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Regression line')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Simple Linear Regression')
plt.show()

# แสดงค่าที่ได้จากการสร้างแบบจำลอง
print(f'Intercept: {model.intercept_}')
print(f'Coefficient: {model.coef_[0]}')
# Out:
# Intercept: 0.2199999999999993
# Coefficient: 0.9514285714285715

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Generate some synthetic data for demonstration
np.random.seed(0)
X = np.random.rand(100, 1) * 10  # Random feature (e.g., house age)
y = 3 * X + np.random.randn(100, 1) * 2  # Target (e.g., house price)

# Initialize the model
model = LinearRegression()

# Fit the model
model.fit(X, y)

# Predict on training data
y_pred = model.predict(X)

# Compute the mean squared error
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse}")

# Plot the results
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('House Age')
plt.ylabel('House Price')
plt.title('Linear Regression Example')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 3.969754594898593

# %%
import numpy as np

# สร้างข้อมูลตัวอย่าง
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 3, 5, 7, 11])

# หาค่า correlation coefficient ด้วย numpy
correlation_matrix = np.corrcoef(x, y)
correlation_coefficient = correlation_matrix[0, 1]

print(f"Correlation Coefficient: {correlation_coefficient}")
# Out:
# Correlation Coefficient: 0.9722718241315028
